# %% [markdown]
# # Visualizing the Mushroom dataset

# %%
import pandas as pd 
import matplotlib.pyplot as plt
# Out:
# C:\Users\Engr. CY\AppData\Local\Temp\ipykernel_3608\714528797.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Read the data and display the first few rows
df = pd.read_csv(r"C:\Users\Engr. CY\Desktop\ArewaDS\Data-Science-Assignment\Visualization_Assignment\mushroom_dataset\mushrooms.csv")
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
# Check the dimension of the dataset
df.shape
# Out:
# (8124, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
df.nunique()
# Out:
# class                        2
# cap-shape                    6
# cap-surface                  4
# cap-color                   10
# bruises                      2
# odor                         9
# gill-attachment              2
# gill-spacing                 2
# gill-size                    2
# gill-color                  12
# stalk-shape                  2
# stalk-root                   5
# stalk-surface-above-ring     4
# stalk-surface-below-ring     4
# stalk-color-above-ring       9
# stalk-color-below-ring       9
# veil-type                    1
# veil-color                   4
# ring-number                  3
# ring-type                    5
# spore-print-color            9
# population                   6
# habitat                      7
# dtype: int64

# %% [markdown]
# # Plotting the distribution of cap shape

# %%
plt.figure(figsize=(8, 6))
df['cap-shape'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Cap Shape')
plt.xlabel('Cap Shape')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Plotting the distribution of cap color

# %%
plt.figure(figsize=(8, 6))
df['cap-color'].value_counts().plot(kind='bar', color='lightgreen')
plt.title('Distribution of Cap Color')
plt.xlabel('Cap Color')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Plotting the distribution of odor

# %%
plt.figure(figsize=(8, 6))
df['odor'].value_counts().plot(kind='bar', color='salmon')
plt.title('Distribution of Odor')
plt.xlabel('Odor')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Plotting  the distribution of class

# %%
plt.figure(figsize=(8, 6))
df['class'].value_counts().plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Distribution of Mushroom Classes')
plt.xlabel('Class')
plt.ylabel('Count')
plt.xticks(rotation=0, labels=['Edible', 'Poisonous'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 7
#       5 plt.xlabel('Class')
#       6 plt.ylabel('Count')
# ----> 7 plt.xticks(rotation=0, labels=['Edible', 'Poisonous'])
#       8 plt.show()
#
# File c:\Users\Engr. CY\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:2042, in xticks(ticks, labels, minor, **kwargs)
#    2040     locs = ax.get_xticks(minor=minor)
#    2041     if labels is not None:
# -> 2042         raise TypeError("xticks(): Parameter 'labels' can't be set "
#    2043                         "without setting 'ticks'")
#    2044 else:
#    2045     locs = ax.set_xticks(ticks, minor=minor)
#
# TypeError: xticks(): Parameter 'labels' can't be set without setting 'ticks'

# %% [markdown]
# # Plotting pie charts for each categorical variable

# %%
categorical_columns = df.select_dtypes(include=['object']).columns


for column in categorical_columns:
    plt.figure(figsize=(8, 6))
    df[column].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90)
    plt.title(f'Distribution of {column}')
    plt.ylabel('')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()
